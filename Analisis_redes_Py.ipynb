# %% [markdown]
# # Análisis de redes con NetworkX - Python

# %%
import networkx as nx

# %% [markdown]
# ## Leer redes

# %%
g = nx.read_graphml("data/ZacharyKarateNetwork.graphml")

# %%
g

# %%
len(g.nodes())
# Out:
# 34

# %%
len(g.edges())
# Out:
# 78

# %%
nx.draw(g)

# %%
nx.write_graphml(G=g, path="ejemplo_escribir_py.graphml")

# %% [markdown]
# ### Caminos

# %%
nx.shortest_path_length(g)
# Out:
# <generator object all_pairs_shortest_path_length at 0x7f53fdcf0350>

# %%
mis_caminos = nx.average_shortest_path_length(g)
mis_caminos
# Out:
# 2.408199643493761

# %%
nx.diameter(g)
# Out:
# 5

# %% [markdown]
# ### Componentes

# %%
nx.number_connected_components(g)
# Out:
# 1

# %%
my_concomp = nx.connected_components(g)

# %%
S = [g.subgraph(c).copy() for c in my_concomp]

# %% [markdown]
# ### Clustering coefficient

# %%
nx.average_clustering(g)
# Out:
# 0.5706384782076823

# %% [markdown]
# ### Grado

# %%
nx.degree(g)
# Out:
# DegreeView({'n0': 16, 'n1': 9, 'n2': 10, 'n3': 6, 'n4': 3, 'n5': 4, 'n6': 4, 'n7': 4, 'n8': 5, 'n9': 2, 'n10': 3, 'n11': 1, 'n12': 2, 'n13': 5, 'n14': 2, 'n15': 2, 'n16': 2, 'n17': 2, 'n18': 2, 'n19': 3, 'n20': 2, 'n21': 2, 'n22': 2, 'n23': 5, 'n24': 3, 'n25': 3, 'n26': 2, 'n27': 4, 'n28': 3, 'n29': 4, 'n30': 4, 'n31': 6, 'n32': 12, 'n33': 17})

# %% [markdown]
# ### Betweenness centrality

# %%
nx.betweenness_centrality(g)
# Out:
# {'n0': 0.43763528138528146,
#  'n1': 0.053936688311688304,
#  'n2': 0.14365680615680618,
#  'n3': 0.011909271284271283,
#  'n4': 0.0006313131313131313,
#  'n5': 0.02998737373737374,
#  'n6': 0.029987373737373736,
#  'n7': 0.0,
#  'n8': 0.05592682780182781,
#  'n9': 0.0008477633477633478,
#  'n10': 0.0006313131313131313,
#  'n11': 0.0,
#  'n12': 0.0,
#  'n13': 0.04586339586339586,
#  'n14': 0.0,
#  'n15': 0.0,
#  'n16': 0.0,
#  'n17': 0.0,
#  'n18': 0.0,
#  'n19': 0.03247504810004811,
#  'n20': 0.0,
#  'n21': 0.0,
#  'n22': 0.0,
#  'n23': 0.017613636363636363,
#  'n24': 0.0022095959595959595,
#  'n25': 0.0038404882154882154,
#  'n26': 0.0,
#  'n27': 0.02233345358345358,
#  'n28': 0.0017947330447330447,
#  'n29': 0.0029220779220779218,
#  'n30': 0.014411976911976909,
#  'n31': 0.13827561327561325,
#  'n32': 0.145247113997114,
#  'n33': 0.30407497594997596}

# %%
nx.edge_betweenness(g)
# Out:
# {('n0', 'n1'): 0.025252525252525245,
#  ('n0', 'n2'): 0.0777876807288572,
#  ('n0', 'n3'): 0.02049910873440285,
#  ('n0', 'n4'): 0.0522875816993464,
#  ('n0', 'n5'): 0.07813428401663694,
#  ('n0', 'n6'): 0.07813428401663695,
#  ('n0', 'n7'): 0.0228206434088787,
#  ('n0', 'n8'): 0.07423959482783014,
#  ('n0', 'n10'): 0.0522875816993464,
#  ('n0', 'n11'): 0.058823529411764705,
#  ('n0', 'n12'): 0.04652406417112298,
#  ('n0', 'n13'): 0.04237189825425121,
#  ('n0', 'n17'): 0.04012392835922248,
#  ('n0', 'n19'): 0.045936960642843,
#  ('n0', 'n21'): 0.040123928359222474,
#  ('n0', 'n31'): 0.1272599949070537,
#  ('n1', 'n2'): 0.023232323232323233,
#  ('n1', 'n3'): 0.0077243018419489,
#  ('n1', 'n7'): 0.007422969187675069,
#  ('n1', 'n13'): 0.01240556828792123,
#  ('n1', 'n17'): 0.01869960105254222,
#  ('n1', 'n19'): 0.014633732280791102,
#  ('n1', 'n21'): 0.01869960105254222,
#  ('n1', 'n30'): 0.032280791104320514,
#  ('n2', 'n3'): 0.022430184194890075,
# ...

# %% [markdown]
# ### Clustering

# %%
nx.clustering(g)
# Out:
# {'n0': 0.15,
#  'n1': 0.3333333333333333,
#  'n2': 0.24444444444444444,
#  'n3': 0.6666666666666666,
#  'n4': 0.6666666666666666,
#  'n5': 0.5,
#  'n6': 0.5,
#  'n7': 1.0,
#  'n8': 0.5,
#  'n9': 0,
#  'n10': 0.6666666666666666,
#  'n11': 0,
#  'n12': 1.0,
#  'n13': 0.6,
#  'n14': 1.0,
#  'n15': 1.0,
#  'n16': 1.0,
#  'n17': 1.0,
#  'n18': 1.0,
#  'n19': 0.3333333333333333,
#  'n20': 1.0,
#  'n21': 1.0,
#  'n22': 1.0,
#  'n23': 0.4,
#  'n24': 0.3333333333333333,
#  'n25': 0.3333333333333333,
#  'n26': 1.0,
#  'n27': 0.16666666666666666,
#  'n28': 0.3333333333333333,
#  'n29': 0.6666666666666666,
#  'n30': 0.5,
#  'n31': 0.2,
#  'n32': 0.19696969696969696,
#  'n33': 0.11029411764705882}
